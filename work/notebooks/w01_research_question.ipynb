# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Marrwan1/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
print("Lane selected: Refresh / Content Opportunity Scoring")
# Out:
# Lane selected: Refresh / Content Opportunity Scoring

# %% [markdown]
# # My lane: Refresh / Content Opportunity Scoring
#
# I want to identify which pages should be prioritized for review or potential refresh based on observable content and search-performance signals.
# I chose this lane because the starter dataset contains page-level signals such as impressions, content age, update recency, average position,
# and CTR, which can help us build a useful prioritization approach.
# The goal is to support a practical review decision, not to claim that the model proves why a page is performing poorly.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
print("Decision, action, and cost of a wrong call defined.")
# Out:
# Decision, action, and cost of a wrong call defined.

# %% [markdown]
# ### Decision, action, and cost of a wrong call
#
# The decision is which pages should be prioritized for review or potential refresh.
# A content or SEO team member could use the ranking to review higher-priority pages first and decide whether a page should be refreshed,
# expanded, or monitored. A wrong recommendation could waste review time on a page that did not need attention
# ,while missing a useful page could delay a potentially valuable refresh.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ### Quick look at the data
#
# The starter dataset contains 30,000 pages. The median content age is 236 days,
# and the median number of impressions over the last 90 days is 731.
# These numbers suggest that there is a large set of pages with measurable content age and search exposure,
# making page prioritization for review a useful direction to investigate.
# These figures do not by themselves show that a page needs a refresh;
# they only support exploring a prioritization approach.

# %%
import os
import subprocess

REPO_URL = "https://github.com/Marrwan1/flyrank-ml-internship"
REPO_DIR = "flyrank-ml-internship"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)

print(os.getcwd())
# Out:
# /content/flyrank-ml-internship/flyrank-ml-internship

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("Claims are framed as observed and decision-support, not causal.")
# Out:
# Claims are framed as observed and decision-support, not causal.

# %% [markdown]
# ### What I can and cannot claim
#
# I can use the dataset to identify observed patterns and support a prioritization approach for deciding which pages to review first.
# I cannot claim that the observed relationships are causal, that a specific feature causes a page to decline,
# or that this analysis predicts or explains Google's ranking algorithm.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
